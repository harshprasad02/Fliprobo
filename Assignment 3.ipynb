# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# # Question Number 1

# %%
def call_page(text):
    url = "https:\\www.amazon.in"
    driver=webdriver.Chrome("chromedriver.exe")
    driver.get(url)
    search_bar = driver.find_element_by_id("twotabsearchtextbox")
    search_button = driver.find_element_by_id("nav-search-submit-text")
    search_bar.send_keys(text)
    search_button.click()

# %%
def enter_element():
    x = input("enter the element :")
    return call_page(x)

# %%
enter_element()
# Out:
# enter the element :phone

# %% [markdown]
# # Question Number 2

# %%
url = "https:\\www.amazon.in"
driver=webdriver.Chrome("chromedriver.exe")
driver.get(url)

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")
search_button = driver.find_element_by_id("nav-search-submit-text")
x = input("Enter here :")
search_bar.send_keys(x)
search_button.click()
# Out:
# Enter here :Smart TV

# %%
Brand_Name = []
Name_of_the_Product = []
Rating = []
No_of_Ratings = []
Price = []
exchange = []
Return = []
Expected_Delivery = []
Availability = []
Other_Details = []
Product_URL = []
next_page = driver.find_elements_by_xpath("//li[@class ='a-normal']//a")
new_page = []
for i in next_page:
    new_page.append(i.get_attribute('href'))

urls=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")]
for url in urls:
    try:
        driver.get(url)
        time.sleep(15)
        Brand_Name.append(driver.find_element_by_xpath("//table[@class = 'a-normal a-spacing-micro']//tbody//tr[2]//td[2]//span").text)
        Name_of_the_Product.append(driver.find_element_by_xpath("//h1[@class = 'a-size-large a-spacing-none']//span").text)
        Rating.append(driver.find_element_by_xpath("//span[@class = 'a-size-medium a-color-base']").text)
        No_of_Ratings.append(driver.find_element_by_id("acrCustomerReviewText").text)       
        Price.append(driver.find_element_by_xpath("//td[@class = 'a-span12']//span").text)
        Expected_Delivery.append(driver.find_element_by_xpath("//div[@class = 'a-section a-spacing-mini']//span").text)        
        Availability.append(driver.find_element_by_xpath("//span[@class = 'a-size-medium a-color-success']").text)   
        Other_Details.append(driver.find_element_by_xpath("//ul[@class = 'a-unordered-list a-vertical a-spacing-mini']").text)        
        Product_URL.append(url) 
        exchange.append(driver.find_element_by_xpath("//div[@class ='a-expander-content a-expander-extend-content a-expander-content-expanded']//div[1]").text)
    except NoSuchElementException:
        Brand_Name.append('-')
        Name_of_the_Product.append('-')
        Rating.append('-')
        No_of_Ratings.append('-')
        Price.append('-')
        Return.append('-')
        Expected_Delivery.append('-')
        Availability.append('-')
        Other_Details.append('-')
        Product_URL.append('-')
for i in range(0,2):
    driver.get(new_page[i])
    try:
        driver.get(url)
        time.sleep(15)
        Brand_Name.append(driver.find_element_by_xpath("//table[@class = 'a-normal a-spacing-micro']//tbody//tr[2]//td[2]//span").text)
        Name_of_the_Product.append(driver.find_element_by_xpath("//h1[@class = 'a-size-large a-spacing-none']//span").text)
        Rating.append(driver.find_element_by_xpath("//span[@class = 'a-size-medium a-color-base']").text)
        No_of_Ratings.append(driver.find_element_by_id("acrCustomerReviewText").text)       
        Price.append(driver.find_element_by_xpath("//td[@class = 'a-span12']//span").text)
        Expected_Delivery.append(driver.find_element_by_xpath("//div[@class = 'a-section a-spacing-mini']//span").text)        
        Availability.append(driver.find_element_by_xpath("//span[@class = 'a-size-medium a-color-success']").text)   
        Other_Details.append(driver.find_element_by_xpath("//ul[@class = 'a-unordered-list a-vertical a-spacing-mini']").text)        
        Product_URL.append(url) 
        exchange.append(driver.find_element_by_xpath("//div[@class ='a-expander-content a-expander-extend-content a-expander-content-expanded']//div[1]").text)
    except NoSuchElementException:
        Brand_Name.append('-')
        Name_of_the_Product.append('-')
        Rating.append('-')
        No_of_Ratings.append('-')
        Price.append('-')
        Return.append('-')
        Expected_Delivery.append('-')
        Availability.append('-')
        Other_Details.append('-')
        Product_URL.append('-')

# %%
len(Other_Details)
# Out:
# 37

# %%
Smarttv = pd.DataFrame({"Brand name": Brand_Name,"Name of the product": Name_of_the_Product,"Rating": Rating,"No. of Rating" : No_of_Ratings
                       ,"Price":Price, "Expected delivery":Expected_Delivery,"Availability":Availability,"other Details":Other_Details,
                       "Product URL":Product_URL})

# %%
Smarttv
# Out:
#      Brand name                                Name of the product  \
# 0       Samsung  Samsung 80 cm (32 Inches) Wondertainment Serie...
# 1       OnePlus  OnePlus 108 cm (43 inches) Y Series Full HD LE...
# 2            LG  LG 80 cm (32 inches) HD Ready Smart LED TV 32L...
# 3           TCL  TCL 126 cm (50 inches) 4K Ultra HD Certified A...
# 4           TCL  TCL 108 cm (43 inches) 4K Ultra HD Certified A...
# 5          Sony  Sony Bravia 138.8 cm (55 inches) 4K Ultra HD S...
# 6          Sony  Sony Bravia 108 cm (43 inches) Full HD Smart L...
# 7          Sony  Sony Bravia 80 cm (32 inches) HD Ready Smart A...
# 8           TCL  TCL 100 cm (40 inches) Full HD Certified Andro...
# 9       OnePlus  OnePlus 80 cm (32 inches) Y Series HD Ready LE...
# 10           MI  Mi 125.7 cm (50 Inches) 4K Ultra HD Android Sm...
# 11      Samsung  Samsung 80 cm (32 inches) Wondertainment Serie...
# 12            -                                                  -
# ...

# %% [markdown]
# # Question Number 4

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.flipkart.com"

# %%
driver.get(url)

# %%
search_flipkart = driver.find_element_by_xpath("//input[@class = '_3704LK']")

# %%
search_flipkart_button = driver.find_element_by_xpath("//button[@class = 'L0Z3Pu']")

# %%
x = str(input("Enter Keyword to search: "))
search_flipkart.send_keys(x)
search_flipkart_button.click()
# Out:
# Enter Keyword to search: Redmi Note 7

# %%
brand_name = []
smart_phone_name = []
colour = []
ram = []
storage = []
primary_camera = []
secondary_camera = []
display_size = []
display_resolution = []
processor = []
processor_cores = []
battery_capacity = []
price = []
product_url = []




urls=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']")]
for url in urls:
    try:
        
        driver.get(url)
        time.sleep(15)
        smart_phone_name.append((driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[1]//table[1]//tbody//tr[3]//td[2]//li")).text)
        colour.append((driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[1]//table[1]//tbody//tr[4]//td[2]//li")).text)
        ram.append((driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[4]//table[1]//tr[2]//td[2]//li")).text)        
        storage.append(driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[4]//table[1]//tr[1]//td[2]//li").text)        
        primary_camera.append(driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[5]//table[1]//tr[2]//td[2]//li").text)        
        secondary_camera.append(driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[5]//table[1]//tr[5]//td[2]//li").text)   
        display_size.append(driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[2]//table[1]//tr[1]//td[2]//li").text)        
        display_resolution.append(driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[2]//table[1]//tr[2]//td[2]//li").text)        
        processor.append(driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[3]//table[1]//tr[2]//td[2]//li").text)        
        processor_cores.append(driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[3]//table[1]//tr[3]//td[2]//li").text)        
        battery_capacity.append(driver.find_element_by_xpath("//div[@class = '_1UhVsV']//div[8]//table[1]//tr[1]//td[2]//li").text)        
        price.append(driver.find_element_by_xpath("//div[@class = '_30jeq3 _16Jk6d']").text)
        product_url.append(url)

    except NoSuchElementException :
        brand_name.append("-")
        smart_phone_name.append("-")
        colour.append("-")
        ram.append("-")
        storage.append("-")
        primary_camera.append("-")
        secondary_camera.append("-")
        display_size.append("-")
        display_resolution.append("-")
        processor.append("-")
        processor_cores.append("-")
        battery_capacity.append("-")
        price.append("-")
        product_url.append("-")

# %%
Ques4=pd.DataFrame({"brand name":brand_name,"smart phone name":smart_phone_name,"colour":colour,
                 "ram":ram,"storage":storage,"primary camera": primary_camera,"secondary camera": secondary_camera,"displaysize":display_size,
                  "display resolution":display_resolution,"processor":processor,"processor cores":processor_cores,"battery capacity":battery_capacity,
                   "price": price,"product url": product_url })
Ques4
# Out:
#    brand name  smart phone name              colour   ram storage  \
# 0           -      Redmi Note 7          Onyx Black  4 GB   64 GB
# 1           -      Redmi Note 7            Ruby Red  4 GB   64 GB
# 2           -      Redmi Note 7       Sapphire Blue  4 GB   64 GB
# 3           -      Redmi Note 7          Onyx Black  3 GB   32 GB
# 4           -      Redmi Note 7       Sapphire Blue  3 GB   32 GB
# 5           -      Redmi Note 7            Ruby Red  3 GB   32 GB
# 6           -  Redmi Note 7 Pro          Nebula Red  6 GB   64 GB
# 7           -  Redmi Note 7 Pro               Black  4 GB   64 GB
# 8           -  Redmi Note 7 Pro         Space Black  6 GB   64 GB
# 9           -  Redmi Note 7 Pro                 Red  4 GB   64 GB
# 10          -            Note 9         Pebble Grey  4 GB   64 GB
# 11          -            Note 9        Shadow Black  4 GB   64 GB
# 12          -            Note 9          Aqua Green  4 GB   64 GB
# ...

# %% [markdown]
# # Question Number 5

# %% [markdown]
# Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
url = "https://www.google.co.in/maps?hl=en&tab=rl&authuser=0"
driver=webdriver.Chrome("chromedriver.exe")
driver.get(url)

# %%
#creating instances for search box and search button present on google maps and asking user for the input
search_bar = driver.find_element_by_id("searchboxinput")
search_button = driver.find_element_by_xpath("//button[@class = 'searchbox-searchbutton']")
x = input("Enter here :")
search_bar.send_keys(x)
search_button.click()
# Out:
# Enter here :New Delhi

# %%
city =driver.current_url
city
# Out:
# 'https://www.google.co.in/maps/place/New+Delhi,+Delhi/@28.5856634,77.1830131,15z/data=!4m5!3m4!1s0x390cfd5b347eb62d:0x52c2b7494e204dce!8m2!3d28.6139391!4d77.2090212?hl=en&authuser=0'

# %%
#importing re (regular expression) library to extract geospatial coordinates
import re
pattern = re.compile(r'\d\d[.]\d\d\d\d\d\d\d,\d\d[.]\d\d\d\d\d\d\d') #here we are setting up the critera to extract coordinate
match = pattern.search(city)
match
# Out:
# <re.Match object; span=(54, 75), match='28.5856634,77.1830131'>

# %%
coordinates =match.group()  #finally extracting coordinates,converting them into string and printing them
print("The geo spatial coordinates are :" ,coordinates)
# Out:
# The geo spatial coordinates are : 28.5856634,77.1830131

# %% [markdown]
# # Question Number 6

# %%
#first writing link of the web page we want to extract data from and then passing the url to drivers

# %%
url_f = "https://trak.in/"

# %%
driver.get(url_f)

#extracting xpath of the "funding details" button present on the page. and extracting url of the button to visit the desired web page.
funding_deals = driver.find_element_by_xpath("//li[@class ='menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-51510']//a")
url_new = funding_deals.get_attribute('href')

driver.get(url_new)

# %%
date = []
startup_name = []
industry = []
sub_vertical = []
city = []
investor = []
investment = []
amount = []
#extracting detailes for the month of july
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-48 dataTable no-footer']//tbody//td[@class = 'column-2']"):
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-48 dataTable no-footer']//tbody//td[@class = 'column-3']"):
    startup_name.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-48 dataTable no-footer']//tbody//td[@class = 'column-4']"):
    industry.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-48 dataTable no-footer']//tbody//td[@class = 'column-5']"):
    sub_vertical.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-48 dataTable no-footer']//tbody//td[@class = 'column-6']"):
    city.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-48 dataTable no-footer']//tbody//td[@class = 'column-7']"):
    investor.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-48 dataTable no-footer']//tbody//td[@class = 'column-8']"):
    investment.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-48 dataTable no-footer']//tbody//td[@class = 'column-9']"):
    amount.append(i.text)

# %%
#extracting detailes for the month of august
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-49 dataTable no-footer']//tbody//td[@class = 'column-2']"):
    date.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-49 dataTable no-footer']//tbody//td[@class = 'column-3']"):
    startup_name.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-49 dataTable no-footer']//tbody//td[@class = 'column-4']"):
    industry.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-49 dataTable no-footer']//tbody//td[@class = 'column-5']"):
    sub_vertical.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-49 dataTable no-footer']//tbody//td[@class = 'column-6']"):
    city.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-49 dataTable no-footer']//tbody//td[@class = 'column-7']"):
    investor.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-49 dataTable no-footer']//tbody//td[@class = 'column-8']"):
    investment.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-49 dataTable no-footer']//tbody//td[@class = 'column-9']"):
    amount.append(i.text)

# %%
#extracting detailes for the month of september
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-50 dataTable no-footer']//tbody//td[@class = 'column-2']"):
    date.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-50 dataTable no-footer']//tbody//td[@class = 'column-3']"):
    startup_name.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-50 dataTable no-footer']//tbody//td[@class = 'column-4']"):
    industry.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-50 dataTable no-footer']//tbody//td[@class = 'column-5']"):
    sub_vertical.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-50 dataTable no-footer']//tbody//td[@class = 'column-6']"):
    city.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-50 dataTable no-footer']//tbody//td[@class = 'column-7']"):
    investor.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-50 dataTable no-footer']//tbody//td[@class = 'column-8']"):
    investment.append(i.text)
for i in driver.find_elements_by_xpath("//table[@class = 'tablepress tablepress-id-50 dataTable no-footer']//tbody//td[@class = 'column-9']"):
    amount.append(i.text)

# %%
track = pd.DataFrame({"Date": date,"Startup Name": startup_name,"Industry/Vertical":industry,"Sub-Vertical":sub_vertical,"City/Location":city,
                     "Investor's Name":investor,"Investment Type":investment,"Amount(in USD)":amount})

# %%
track
# Out:
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# ...
